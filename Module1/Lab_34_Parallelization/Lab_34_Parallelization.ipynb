# %% [markdown]
# # Parallelization Lab
# In this lab, you will be leveraging several concepts you have learned to obtain a list of links from a web page and crawl and index the pages referenced by those links - both sequentially and in parallel. Follow the steps below to complete the lab.

# %% [markdown]
# ### Step 1: Use the requests library to retrieve the content from the URL below.

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
# your code 
response = requests.get(url).content
response
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Data science - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"6a00a12e-56f8-4229-9af5-fe02055b0098","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Data_science","wgTitle":"Data science","wgCurRevisionId":1080105804,"wgRevisionId":1080105804,"wgArticleId":35458904,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description matches Wikidata","Use dmy dates from August 2021","All articles with links needing disambigua
# ...

# %% [markdown]
# ### Step 2: Use BeautifulSoup to extract a list of all the unique links on the page.

# %%
from bs4 import BeautifulSoup

# %%
# your code here
step2 = BeautifulSoup(response, "lxml")
step2
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Data science - Wikipedia</title>
# ...

# %%
tags= step2.find_all('a', {"href": True})
tags
# Out:
# [<a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>,
#  <a href="/wiki/Information_science" title="Information science">information science</a>,
#  <a class="image" href="/wiki/File:PIA23792-1600x1200(1).jpg"><img alt="" class="thumbimage" data-file-height="1200" data-file-width="1600" decoding="async" height="188" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/250px-PIA23792-1600x1200%281%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/375px-PIA23792-1600x1200%281%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/45/PIA23792-1600x1200%281%29.jpg/500px-PIA23792-1600x1200%281%29.jpg 2x" width="250"/></a>,
#  <a class="internal" href="/wiki/File:PIA23792-1600x1200(1).jpg" title="Enlarge"></a>,
#  <a href="/wiki/Comet_NEOWISE" title="Comet NEOWISE">Comet NEOWISE</a>,
# ...

# %%
for link in tags:
  print(link['href'])
# Out:
# #mw-head
# #searchInput
# /wiki/Information_science
# /wiki/File:PIA23792-1600x1200(1).jpg
# /wiki/File:PIA23792-1600x1200(1).jpg
# /wiki/Comet_NEOWISE
# /wiki/Astronomical_survey
# /wiki/Space_telescope
# /wiki/Wide-field_Infrared_Survey_Explorer
# /wiki/Machine_learning
# /wiki/Data_mining
# /wiki/File:Kernel_Machine.svg
# /wiki/Statistical_classification
# /wiki/Cluster_analysis
# /wiki/Regression_analysis
# /wiki/Anomaly_detection
# /wiki/Data_Cleaning
# /wiki/Automated_machine_learning
# /wiki/Association_rule_learning
# /wiki/Reinforcement_learning
# /wiki/Structured_prediction
# /wiki/Feature_engineering
# /wiki/Feature_learning
# /wiki/Online_machine_learning
# /wiki/Semi-supervised_learning
# /wiki/Unsupervised_learning
# /wiki/Learning_to_rank
# /wiki/Grammar_induction
# /wiki/Supervised_learning
# /wiki/Statistical_classification
# /wiki/Regression_analysis
# /wiki/Decision_tree_learning
# /wiki/Ensemble_learning
# /wiki/Bootstrap_aggregating
# ...

# %%
lst =set()   #avec set only unique element
for link in tags:
  lst.add(link['href'])
lst
len(lst)
# Out:
# 447

# %%
lst2 =[]
for link in tags:
  lst2.append(link['href'])
lst2
len(lst2)
# Out:
# 510

# %%
lst_link_unique = list(set([link['href'] for link in tags]))

# %% [markdown]
# ### Step 3: Use list comprehensions with conditions to clean the link list.
# There are two types of links, absolute and relative. Absolute links have the full URL and begin with http while relative links begin with a forward slash (/) and point to an internal page within the wikipedia.org domain. Clean the respective types of URLs as follows.
#
# Absolute Links: Create a list of these and remove any that contain a percentage sign (%).
#
# Relative Links: Create a list of these, add the domain to the link so that you have the full URL, and remove any that contain a percentage sign (%).
#
# Combine the list of absolute and relative links and ensure there are no duplicate

# %%
domain = 'http://wikipedia.org'

# %%
# your code here
absolute = []
for link in lst_link_unique :
    if link.startswith('http') and '%' not in link:
        absolute.append(link)
print (absolute)
# Out:
# ['https://statmodeling.stat.columbia.edu/2013/11/14/statistics-least-important-part-data-science/', 'http://www.datascienceassn.org/about-data-science', 'https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/', 'https://stats.wikimedia.org/#/en.wikipedia.org', 'https://benfry.com/phd/dissertation/2.html', 'https://api.semanticscholar.org/CorpusID:9743327', 'https://foundation.wikimedia.org/wiki/Privacy_policy', 'http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/', 'https://web.archive.org/web/20190620184935/https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/', 'https://en.wikipedia.org/w/index.php?title=Template:Data&action=edit', 'https://id.wikipedia.org/wiki/Ilmu_data', 'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en', 'https://web.archive.org/web/20141109113411
# ...

# %%
relative = []
for link in lst_link_unique :
    if link.startswith('/') and '%' not in link:
        relative.append(link)
print (relative)
# Out:
# ['/wiki/Category:Articles_with_links_needing_disambiguation_from_March_2022', '//pubmed.ncbi.nlm.nih.gov/19265007', '/w/index.php?title=Data_science&action=edit&section=4', '/w/index.php?title=Data_science&action=info', '/wiki/Information_visualization', '/wiki/Data_compression', '/wiki/Canonical_correlation', '/wiki/Jim_Gray_(computer_scientist)', '/wiki/Peter_Naur', '/wiki/William_S._Cleveland', '/wiki/Category:Short_description_matches_Wikidata', '/w/index.php?title=Data_science&action=edit&section=6', '/wiki/Temporal_difference_learning', '/wiki/DBSCAN', '/wiki/Analysis', '//en.wikipedia.org/wiki/Wikipedia:Contact_us', '/wiki/Occam_learning', '/wiki/Memtransistor', '/wiki/Support-vector_machine', '/wiki/Doi_(identifier)', '/wiki/Wikipedia:File_Upload_Wizard', '/wiki/American_Statistical_Association', '/wiki/Transformer_(machine_learning_model)', '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License', '/wiki/Generative_adversarial_
# ...

# %%
a=set(absolute+relative) #ajout de two list in set have unique value
list(a)  #transform set in list
# Out:
# ['/wiki/Category:Articles_with_links_needing_disambiguation_from_March_2022',
#  'https://statmodeling.stat.columbia.edu/2013/11/14/statistics-least-important-part-data-science/',
#  'http://www.datascienceassn.org/about-data-science',
#  '//pubmed.ncbi.nlm.nih.gov/19265007',
#  '/w/index.php?title=Data_science&action=edit&section=4',
#  '/w/index.php?title=Data_science&action=info',
#  '/wiki/Information_visualization',
#  'https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/',
#  '/wiki/Data_compression',
#  '/wiki/Canonical_correlation',
#  '/wiki/Jim_Gray_(computer_scientist)',
#  '/wiki/Peter_Naur',
#  '/wiki/William_S._Cleveland',
#  '/wiki/Category:Short_description_matches_Wikidata',
#  '/w/index.php?title=Data_science&action=edit&section=6',
#  '/wiki/Temporal_difference_learning',
#  '/wiki/DBSCAN',
#  '/wiki/Analysis',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '/wiki/Occam_learning',
# ...

# %% [markdown]
# ### Step 4: Use the os library to create a folder called wikipedia and make that the current working directory.

# %%
import os

# %%
# your code here
# Directory
directory = "wikipedia"
  
# Parent Directory path
parent_dir = r"C:\Users\rana_\IronhackDA\DAFT_212\Module_1\Lab_34_Parallelization"
  
# Path
path = os.path.join(parent_dir, directory)
  
# Create the directory
# 'wikipedia' in
# '\Users\Lenovo\Documents\Ironhack\DATA'
os.mkdir(path)
print("Directory '% s' created" % directory)
# Out:
# Directory 'wikipedia' created

# %% [markdown]
# ### Step 5: Write a function called index_page that accepts a link and does the following.
# Tries to request the content of the page referenced by that link.
#
# Slugifies the filename using the slugify function from the python-slugify library and adds a .html file extension.
#
#       If you don't already have the python-slugify library installed, you can pip install it as follows:
#       $ pip3 install python-slugify.
#
#       To import the slugify function, you would do the following: from slugify import slugify.
#
#       You can then slugify a link as follows slugify(link).
#
# Creates a file in the wikipedia folder using the slugified filename and writes the contents of the page to the file.
#
# If an exception occurs during the process above, just pass.

# %%
pip install python-slugify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from slugify import slugify

# %%
# your code here
def index_page(url):
    try:
        response = requests.get(url).content
        filename=slugify(url) + ".html"
        with open (r'C:\Users\rana_\IronhackDA\DAFT_212\Module_1\Lab_34_Parallelization\wikipedia' + '\ ' + filename, 'wb') as f:
            f.write(response)
    except:
        pass

# %%
def index_page2(url):
    try:
        response = requests.get(url).content
        filename=slugify(url) + ".html"
        with open (r'C:\Users\rana_\IronhackDA\DAFT_212\Module_1\Lab_34_Parallelization\wikipedia' + '\ ' + filename, 'w') as f:
            f.write("response") #c'est le text "response" qui est dans le fichier
    except:
        pass

# %% [markdown]
# ### Step 6: Sequentially loop through the list of links, running the index_page function each time.
# Remember to include %%time at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
# %%time
for link in lst_link_unique:
    index_page(link)
# Out:
# Wall time: 35.1 s

# %%
# your code here

# %% [markdown]
# ### Step 7: Perform the page indexing in parallel and note the difference in performance.
# Remember to include %%time at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
import multiprocessing

# %%
# %%time
pool = multiprocessing.Pool()
result = pool.map(index_page, lst_link_unique) #index_page: fonction, lst_link_unique: list
pool.terminate()
pool.join()
print(result)
