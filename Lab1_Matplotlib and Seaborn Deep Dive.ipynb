# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, label='linear')


plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Linear relation")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(3, 5))
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x, z, label='quadratic')

plt.xlabel('x label')
plt.ylabel('z label')

plt.title("quadratic Plot")
plt.legend()
plt.show()

# %%
plt.plot(x, y, label='linear')
plt.plot(x, z, label='quadratic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Linear vs Non Linear Plots")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2)
ax1.plot(x,y)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')  

ax2.plot(x,z)

ax2.set_title('Quadratic PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(4,4.5))  


ax1.plot(x,y)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')  

ax2.plot(x,z)

ax2.set_title('Quadratic PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,100)
y = x **2
y =np.exp(x)

fig, [ax1, ax2] = plt.subplots(1,2)  


ax1.plot(x,x**2)
ax1.set_title('LINEAR PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')  

ax2.plot(x,np.exp(x))

ax2.set_title('Exponential PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')


plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2)  


ax1.plot(x,x**2,label='LEG1') #POUR LA LEGENDE LABEL LEG )
ax1.set_title('LINEAR PLOT') 
ax1.legend()
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')  

ax2.plot(x,np.exp(x),label='LEG2')
ax2.set_title('Exponential PLOT')
ax2.legend()
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')


plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv(r'C:\Users\rana_\IronhackDA\DAFT_212\module_2\Lab_1_Matplotlib-and-Seaborn\Fitbit2.csv') 
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fitbit_median_months=fitbit[['Steps','Months_encoded']].groupby(['Months_encoded']).agg({'Steps':'median'})
fitbit_median_months
fitbit_median_months.plot.bar()
# They are more active in April

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
fitbit_median_work_or_weekend=fitbit[['Steps','Work_or_Weekend']].groupby(['Work_or_Weekend']).agg({'Steps':'median'})
fitbit_median_work_or_weekend
fitbit_median_work_or_weekend.plot.bar()

# On work days we practice more
# Out:
# <AxesSubplot:xlabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
for i in fitbit.columns[6:9]:
    print(i)
    plt.scatter(fitbit['Steps'], fitbit[i])
    plt.show()
# Out:
# Minutes Lightly Active
# Minutes Fairly Active
# Minutes Very Active

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic =pd.read_csv(r'C:\Users\rana_\IronhackDA\DAFT_212\module_2\Lab_1_Matplotlib-and-Seaborn\titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
numerical_variables = titanic.select_dtypes(exclude=['object']).columns.tolist()
numerical_variables
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# CATEGORICAL VARIABLES
non_numerical_variables = titanic.select_dtypes(include=['object']).columns.tolist()
non_numerical_variables
# Out:
# ['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.rcParams["figure.figsize"] = [12,6]

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, [ax1, ax2,ax3] = plt.subplots(1,3)  

ax1.hist(titanic['Age'], bins =10)
ax2.hist(titanic['Age'], bins = 20)
ax3.hist(titanic['Age'], bins =50)

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
The larger the bin sizes, the fewer bins there will be to cover the whole range of data.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(data =titanic, x = 'Age' )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic['Gender'].value_counts().plot(kind="bar")

 

plt.show()

# %%
titanic['Gender'].value_counts()
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %%
# Method 2 - seaborn
# your code here
sns.countplot(x='Gender', data=titanic)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
titanic['Pclass'].value_counts().plot(kind="bar")

 

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(data =titanic['Age'] )
# Out:
# <AxesSubplot:>

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
max of age : 80, min=0 , Q3=38, Q1=22, median =29
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(x="Age", data=titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
A violin shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
x = titanic['Fare']
y = titanic['Age']
plt.scatter(x,y)
plt.xlabel('Fare')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
# Method 2 - seaborn
# your code here
sns.relplot(data=titanic,x='Fare',y='Age')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
heatmap = sns.heatmap(titanic.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# #### What are the most correlated features?

# %%
titanic.corr().unstack().sort_values().drop_duplicates()
# Out:
# Pclass       Fare          -0.558683
#              Age           -0.425965
#              Survived      -0.338481
# SibSp        Age           -0.260706
# Parch        Age           -0.145488
# Survived     Age           -0.065376
# SibSp        PassengerId   -0.055224
# Pclass       PassengerId   -0.038354
# SibSp        Survived      -0.035322
# Survived     PassengerId   -0.005007
# Parch        PassengerId    0.008942
#              Pclass         0.018322
# PassengerId  Age            0.025325
# Fare         PassengerId    0.031128
# Pclass       SibSp          0.060832
# Survived     Parch          0.081629
# SibSp        Fare           0.160349
# Age          Fare           0.171355
# Parch        Fare           0.221635
# Survived     Fare           0.257307
# SibSp        Parch          0.373587
# PassengerId  PassengerId    1.000000
# dtype: float64

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
titanic.boxplot(column="Age",by="Pclass")
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Pclass'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.boxplot(x="Age",y="Gender",data=titanic)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Gender'>
